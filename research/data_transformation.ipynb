# %% [markdown]
# # Data Transformation
# This notebook splits the ingested CSV into train/test and saves under `artifacts/data_transformation` using project configuration.

# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\2021ICTS28\\Desktop\\red_wine_quality_prediction\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\2021ICTS28\\Desktop\\red_wine_quality_prediction'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from redwine.constants import *
from redwine.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
        )

        return data_transformation_config

# %%
import os
from redwine import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    
    ## Note: You can add different data transformation techniques such as Scaler, PCA and all
    #You can perform all kinds of EDA in ML cycle here before passing this data to the model

    # I am only adding train_test_spliting cz this data is already cleaned up


    def train_test_spliting(self):
        data = pd.read_csv(self.config.data_path)

        # Split the data into training and test sets. (0.75, 0.25) split.
        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"),index = False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"),index = False)

        logger.info("Splited data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
# Ensure data is ingested and CSV exists
from redwine.constants import CONFIG_FILE_PATH
from redwine.utils.common import read_yaml
from redwine.pipeline.stage01_data_ingestion import DataIngestionTrainingPipeline
import os

_cfg = read_yaml(CONFIG_FILE_PATH)
_csv_path = _cfg.data_validation.unzip_data_dir

if not os.path.exists(_csv_path):
    DataIngestionTrainingPipeline().main()
# Out:
# [2025-12-17 13:58:18,601: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-12-17 13:58:18,602: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-12-17 13:58:18,603: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-12-17 13:58:18,605: INFO: common: yaml file: schema.yaml loaded successfully]
# [2025-12-17 13:58:18,605: INFO: common: created directory at: artifacts]
# [2025-12-17 13:58:18,606: INFO: common: created directory at: artifacts/data_ingestion]
# [2025-12-17 13:58:19,832: INFO: data_ingestion: artifacts/data_ingestion/data.zip download! with following info:
# Connection: close
# Content-Length: 23329
# Cache-Control: max-age=300
# Content-Security-Policy: default-src 'none'; style-src 'unsafe-inline'; sandbox
# Content-Type: application/zip
# ETag: "c69888a4ae59bc5a893392785a938ccd4937981c06ba8a9d6a21aa52b4ab5b6e"
# Strict-Transport-Security: max-age=31536000
# X-Content-Type-Options: nosniff
# ...

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_spliting()
except Exception as e:
    raise e
# Out:
# [2025-12-17 13:58:33,793: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-12-17 13:58:33,794: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-12-17 13:58:33,796: INFO: common: yaml file: schema.yaml loaded successfully]
# [2025-12-17 13:58:33,796: INFO: common: created directory at: artifacts]
# [2025-12-17 13:58:33,797: INFO: common: created directory at: artifacts/data_transformation]
# [2025-12-17 13:58:33,808: INFO: 2148425976: Splited data into training and test sets]
# [2025-12-17 13:58:33,809: INFO: 2148425976: (1199, 12)]
# [2025-12-17 13:58:33,810: INFO: 2148425976: (400, 12)]
# (1199, 12)
# (400, 12)
